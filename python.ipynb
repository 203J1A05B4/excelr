# %%
import numpy as np #used for matrixces
a=np.array([1,2,3,4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape #how many rows and number of elements
# Out:
# (4,)

# %%
b=np.array([(1,2,3),(4,5,6)])

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.shape
# Out:
# (2, 3)

# %%
a.max()
# Out:
# 4

# %%
b.min()
# Out:
# 1

# %%
a.prod()
# Out:
# 24

# %%
b.resize(3,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-92010508deca> in <cell line: 1>()
# ----> 1 b.resize(3,2)
#
# AttributeError: 'list' object has no attribute 'resize'

# %%
b=b.reshape(4,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-93587135e9c9> in <cell line: 1>()
# ----> 1 b=b.reshape(4,2)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
c=np.array([(1,2,3,4),(4,5,6,7)])

# %%
c
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
c.sum(axis=1) #col sum
# Out:
# array([10, 22])

# %%
c.sum(axis=0) #row sum
# Out:
# array([ 5,  7,  9, 11])

# %%
import pandas as pd
df=pd.DataFrame({'col1':['A','B','B','A'],'col2':[1,2,2,3]})

# %%
df
# Out:
#   col1  col2
# 0    A     1
# 1    B     2
# 2    B     2
# 3    A     3

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#   col1  col2
# 2    B     2

# %%
df1=df.drop_duplicates()

# %%
df1
# Out:
#   col1  col2
# 0    A     1
# 1    B     2
# 3    A     3

# %%
df2=df1.reset_index()

# %%
df2
# Out:
#    index col1  col2
# 0      0    A     1
# 1      1    B     2
# 2      3    A     3

# %%
df3=df2.drop('index',axis=1)

# %%
df3
# Out:
#   col1  col2
# 0    A     1
# 1    B     2
# 2    A     3
