# %% [markdown]
# <a href="https://colab.research.google.com/github/203J1A05B4/excelr/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Universities_Clustering.csv')

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.iloc[0:5]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
df.iloc[:,:]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#visualazation in python
plt.hist(df['SAT'],color='red',edgecolor='green',bins=5)
# Out:
# (array([ 4.,  0.,  3., 11.,  7.]),
#  array([1005., 1087., 1169., 1251., 1333., 1415.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['SAT'],color='red',edgecolor='green',)
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['SAT'],color='red',edgecolor='green',)
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.title('Universities')
plt.show()

# %%
plt.hist(df['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Accept'],color='pink')
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Accept'],color='pink',edgecolor='yellow')
plt.hist(df['SAT'],color='green',edgecolor='red')
plt.hist(df['Top10'],color='blue',edgecolor='black')
plt.hist(df['Univ'],color='orange',edgecolor='black')
plt.hist(df['Univ'],color='blue',edgecolor='black')
plt.hist(df['SFRatio'],color='orange',edgecolor='black')
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.title('Universities')
plt.show()

# %%
plt.hist(df['Univ'],color='blue',edgecolor='black')
# Out:
# (array([3., 2., 3., 2., 2., 3., 2., 3., 2., 3.]),
#  array([ 0. ,  2.4,  4.8,  7.2,  9.6, 12. , 14.4, 16.8, 19.2, 21.6, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Accept'],color='blue',edgecolor='black')
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
#histogra of accept column
sns.histplot(df['Accept'])
plt.xlabel('Accept')
plt.ylabel('Frequency')
plt.title('Universities')
plt.show()

# %%
import warnings   #remove warnings
warnings.filterwarnings('ignore')
sns.distplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
#scatter plot
plt.plot(df['Accept'],df['SAT'],'go') #bo stands for blue color surface
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Universities')
plt.show()

# %%
sns.pairplot(df) #it give all histograms and scatter plots in dataframe

# %%
sns.pairplot(df.iloc[1:4,1:3])

# %%
help(plt.plot) #help the info
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.boxplot(df['Accept'])
plt.show()

# %%
plt.boxplot(df['SAT'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x797d8ac87340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x797d8ac843d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x797d8ac84c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x797d8afff130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x797d8affe470>],
#  'means': []}

# %%
plt.figure(figsize=(4,4)) #figure fun used o resize the figure in visualization
plt.boxplot(df['SAT'],vert=False)
plt.show()

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
